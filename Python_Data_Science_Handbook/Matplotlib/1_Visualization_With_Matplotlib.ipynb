# %% [markdown]
# # Visualization with Matplotlib

# %% [markdown]
# ## General Matplotlib Tips

# %% [markdown]
# ### Importing Matplotlib

# %%
# !conda install -y matplotlib
# Out:
# done
# done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# The `plt` is what we will use most often

# %% [markdown]
# ### Setting Styles

# %% [markdown]
# We will use the `plt.style` directive, whith the `classic` style

# %%
plt.style.use('classic')

# %% [markdown]
# ### `show()` or no `show()`? How to Display Your Plots

# %% [markdown]
# #### Plotting from a script

# %% [markdown]
# `plt.show()` starts an event loop, looks for all currently active figure objects, and opens one or more interactive windows that display your figure or figures

# %%
# ------- file: myplot.py ------
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# #### Plotting from an IPython shell

# %% [markdown]
# IPython is built to work with Matplolib

# %%
# %matplotlib
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: <object object at 0x7f961865a570>

# %% [markdown]
# Some changes will not draw automatically: to force an update, use `plt.draw()`

# %% [markdown]
# #### Plotting from an IPython notebook

# %% [markdown]
# Can be done with `%matplotlib` command.
# Two modes:
# - `%matplotlib notebook` to open interactive plots
# - `%matplotlib inline` to generate static images

# %%
# %matplotlib inline

# %% [markdown]
# ### Saving Figures to File

# %% [markdown]
# Saving a figure can be done using the `savefig()` command

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
fig.savefig('my_figure.png')
# Out:
# <div id='81369f54-c76e-410e-aaf2-c0f7dd7e027c'></div>

# %% [markdown]
# To confirm, let's display it using IPython `Image` object

# %%
from IPython.display import Image
Image("my_figure.png")

# %% [markdown]
# Many supported filetypes

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## Two Interfaces for the Price of One

# %% [markdown]
# - A convenient MATLAB-style state-based interface
# - A more powerful object-oriented interface

# %% [markdown]
# ### MATLAB-style Interface

# %% [markdown]
# MATLAB-style tools are contained in `plt` interface

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# Important to note: this interface is stateful and keeps tracks of the current figure and axes. We can get the reference using the `plt.gcf()` (get current figure) and `plt.gca()` (get current axes)

# %% [markdown]
# #### Oject-oriented interface

# %% [markdown]
# This interface is avalable for more complicated situations. Plotting functions are methods of explicit `Figure` and `Axes` objects

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
