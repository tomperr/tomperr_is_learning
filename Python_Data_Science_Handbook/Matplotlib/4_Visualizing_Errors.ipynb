# %% [markdown]
# # Visualizing Errors

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Basic Errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %% [markdown]
# `fmt` has the same behavior and goal as `linestyle` for `plt.plot`. The errorbars has many customization parameters.

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# ## Continuous Errors

# %% [markdown]
# No builtin routine to do so, but it relatively easy to combine `plt.plot` and `plt.fill_between` for a useful result
