# %% [markdown]
# # Simple Scatter Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Scatter Plots with `plt.plot`

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# Many different markers: `['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']`

# %% [markdown]
# They can be used together

# %%
plt.plot(x, y, '-ok');

# %% [markdown]
# `plt.plot` has a lot of different arguments

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ## Scatter Plots with `plt.scatter`

# %% [markdown]
# Very similar to `plt.plot` but only to scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale
# Out:
# /tmp/ipykernel_141881/970815911.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar();  # show color scale

# %% [markdown]
# Let's a real dataset to get better example

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# ## `plot` versus `scatter`: A Note On Efficiency

# %% [markdown]
# `plot` is more efficient on large datasets, because `scatter` has the capability to render a different size and/or color for each point, so there is more computation.
